# %% [markdown]
# # Full-Corpus Composer Classification
#
# This is my extension to the team notebook (`Final.ipynb`).
#
# The final models were trained on 300 of the 1,637 files (75 per composer) because
# loading every piano-roll window as float32 with the 5x augmented copies needs more
# than 10 GB of RAM. I wanted to know how much accuracy that cap is costing us, so
# this notebook removes it and reruns the exact same setup on the full corpus.
#
# Question: does training on all the data help more than the hyperparameter tuning
# we already did?
#
# What I changed vs the team notebook:
#
# - no file cap (but I also rerun the 75-cap with this same code, as the baseline)
# - windows stored as uint8/int16 instead of float32, and transposition applied
#   randomly inside tf.data instead of pre-computing 5 copies. Same augmentation
#   idea, about 25x less memory, which is what makes the full corpus fit.
# - added piece-level evaluation (average the window probabilities of each file),
#   since that matches how the model would actually be used
# - models are always trained fresh in-session, no reloading old checkpoints
#
# Everything else is identical on purpose: same seed, same split ratios, same window
# parameters, same architectures, same best configs from the grid search.
#
# To run: upload to Colab, switch the runtime to GPU, run the dataset cell below,
# then Run all. Takes about 20-40 min on the free T4. Extracted windows get cached
# to build/fc_cache/ so a rerun after a disconnect skips the parsing.

# %% [markdown]
# ## 1. Setup

# %%
# Must run before any TensorFlow import so env vars and CUDA libs are in place
import os, sys

# Prepend notebook directory so utilsTF.py is importable
sys.path.insert(0, os.path.dirname(os.path.abspath("full_corpus_experiment.ipynb")))

from utilsTF import load_cuda_libraries, configure_tensorflow

load_cuda_libraries()      # pre-load nvidia .so files into process memory
configure_tensorflow()     # set XLA_FLAGS and TF_CPP_MIN_LOG_LEVEL before TF loads
# Out:
# ✓ Loaded CUDA libraries from /home/maxim/miniconda3/envs/511-team-project-2/lib/python3.11/site-packages/nvidia

# %%
from utilsTF import test_gpu

test_gpu()   # enable memory growth and report available GPUs
# Out:
# ✓ GPU setup complete - 1 GPU(s) available
# 1

# %%
import os, random, hashlib, json, warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pretty_midi
pretty_midi.pretty_midi.MAX_TICK = 1e7
warnings.filterwarnings("ignore")

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_recall_fscore_support,
                             classification_report, confusion_matrix)
from sklearn.utils.class_weight import compute_class_weight

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.16.1
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ----------------------------- CONFIG -----------------------------
# Point this at the folder containing Bach/, Beethoven/, Chopin/, Mozart/.
# Colab example after unzipping: "/content/dataset_4composers"
DATASET_PATH = "data"          # Francisco/data if run from the Francisco folder

TARGET_COMPOSERS = ["Bach", "Beethoven", "Chopin", "Mozart"]

# --- identical to the team notebook (Final.ipynb) ---
SEQ_LEN, SEQ_STRIDE = 100, 50          # LSTM: notes per window / hop
PR_FS, PR_TIME, PR_PITCH, PR_STRIDE = 8, 128, 128, 64  # CNN piano roll
TEST_SIZE, VAL_SIZE = 0.15, 0.15
BATCH_SIZE, MAX_EPOCHS, PATIENCE, SEED = 64, 60, 8, 42
MAX_WINDOWS_PER_FILE = 20              # kept to match the team notebook
AUG_SEMITONES = [-2, -1, 1, 2]         # applied randomly on the fly (train only)

# Best grid-search configs from the team notebook — no re-tuning here.
LSTM_CFG = {"lr": 1e-3,  "dropout": 0.3}
CNN_CFG  = {"lr": 5e-4,  "dropout": 0.3}
USE_BATCHNORM = True                   # flip to False for the BatchNorm ablation

# The experiment variable: file cap per composer. None = full corpus.
EXPERIMENT_CAPS = [75, None]

ARTIFACTS_DIR = Path("build/fc_artifacts"); ARTIFACTS_DIR.mkdir(parents=True, exist_ok=True)
OUT_DIR = Path("build/fc_results");        OUT_DIR.mkdir(parents=True, exist_ok=True)
CACHE_DIR = Path("build/fc_cache");        CACHE_DIR.mkdir(parents=True, exist_ok=True)

# ~2x faster conv training on NVIDIA GPUs; harmless elsewhere. The models
# keep their softmax in float32 (see build_cnn/build_lstm) as Keras recommends.
if tf.config.list_physical_devices("GPU"):
    tf.keras.mixed_precision.set_global_policy("mixed_float16")
    print("Mixed precision enabled (float16 compute, float32 softmax).")

def set_seeds(seed=SEED):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed); np.random.seed(seed); tf.random.set_seed(seed)

set_seeds()
LABEL2IDX = {c: i for i, c in enumerate(TARGET_COMPOSERS)}
IDX2LABEL = {i: c for c, i in LABEL2IDX.items()}
print("Config ready. Caps to compare:", EXPERIMENT_CAPS)
# Out:
# Mixed precision enabled (float16 compute, float32 softmax).
# Config ready. Caps to compare: [75, None]

# %% [markdown]
# ### Getting the dataset on Colab (skip if running locally)
#
# Uncomment ONE option. Option A downloads the public Kaggle dataset directly
# (no credentials needed) and keeps only the four target composers.

# %%
# !curl -sL -o midi-classic-music.zip \
  "https://www.kaggle.com/api/v1/datasets/download/blanderbuss/midi-classic-music"
import zipfile, os
z = zipfile.ZipFile("midi-classic-music.zip")
for info in z.infolist():
    parts = info.filename.split("/")
    if len(parts) >= 3 and parts[0] == "midiclassics" and parts[1] in TARGET_COMPOSERS and not info.is_dir():
        dest = os.path.join("data", parts[1], *parts[2:])
        os.makedirs(os.path.dirname(dest), exist_ok=True)
        with z.open(info) as src, open(dest, "wb") as dst:
            dst.write(src.read())
DATASET_PATH = "data"
print("Dataset ready:", os.listdir("data"))
# Out:
# Dataset ready: ['Bach', 'Beethoven', 'Chopin', 'Mozart']

# %% [markdown]
# ## 2. Collect, de-duplicate, and validate files
#
# Identical rules to the team notebook: composer inferred from the path
# (exactly-one-match), MD5 de-duplication, drop unreadable files and files too
# short to yield one window.

# %%
def infer_composer(path, targets=TARGET_COMPOSERS):
    matches = [c for c in targets if c.lower() in str(path).lower()]
    return matches[0] if len(matches) == 1 else None

records = []
for ext in ("*.mid", "*.midi", "*.MID", "*.MIDI"):
    for f in Path(DATASET_PATH).rglob(ext):
        comp = infer_composer(f)
        if comp is not None:
            records.append({"path": str(f), "composer": comp})
raw_df = (pd.DataFrame(records).drop_duplicates("path")
          .sort_values("path").reset_index(drop=True))
assert len(raw_df) > 0, "No MIDI files found - check DATASET_PATH"

def md5_of(path, chunk=1 << 20):
    h = hashlib.md5()
    with open(path, "rb") as fh:
        for block in iter(lambda: fh.read(chunk), b""):
            h.update(block)
    return h.hexdigest()

raw_df["md5"] = raw_df["path"].map(md5_of)
dedup_df = raw_df.drop_duplicates("md5").reset_index(drop=True)
print(f"Files: {len(raw_df)}  after de-dup: {len(dedup_df)}")

def probe_midi(path):
    try:
        pm = pretty_midi.PrettyMIDI(path)
        return sum(len(i.notes) for i in pm.instruments)
    except Exception:
        return -1

dedup_df["n_notes"] = dedup_df["path"].map(probe_midi)   # ~3-5 min on full corpus
clean_df = dedup_df[dedup_df["n_notes"] >= SEQ_LEN].reset_index(drop=True)
print(f"Usable files: {len(clean_df)}")
print(clean_df["composer"].value_counts().reindex(TARGET_COMPOSERS))
# Out:
# Files: 1630  after de-dup: 1610
# Usable files: 1605
# composer
# Bach         1012
# Beethoven     207
# Chopin        132
# Mozart        254
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Feature extraction
#
# The team notebook ran out of RAM because it stored float32 windows with the 4
# transposed copies pre-computed. Here I store base windows only, as uint8 (binary
# piano rolls) and int16 (pitch tokens). The full corpus fits in well under 1 GB.
#
# Windows also carry a file_id so predictions can be aggregated back to piece
# level at evaluation time.

# %%
def extract_both(path):
    """Parse the MIDI file ONCE and derive both representations from it.
    (Parsing dominates extraction time; the team notebook parsed twice.)"""
    try:
        pm = pretty_midi.PrettyMIDI(path)
    except Exception:
        return None, None
    notes = [(n.start, n.pitch) for inst in pm.instruments
             if not inst.is_drum for n in inst.notes]
    seq = None
    if len(notes) >= SEQ_LEN:
        notes.sort(key=lambda x: x[0])
        seq = np.array([p for _, p in notes], dtype=np.int16)
    roll = None
    if len(pm.instruments) > 0:
        r = pm.get_piano_roll(fs=PR_FS)
        if r.shape[1] >= PR_TIME:
            roll = (r > 0).astype(np.uint8)
    return seq, roll

def windows_1d(seq, size, stride, cap=MAX_WINDOWS_PER_FILE):
    out = []
    for start in range(0, len(seq) - size + 1, stride):
        out.append(seq[start:start + size])
        if cap is not None and len(out) >= cap:
            break
    return out

def windows_2d(roll, size, stride, cap=MAX_WINDOWS_PER_FILE):
    out = []
    for start in range(0, roll.shape[1] - size + 1, stride):
        out.append(roll[:, start:start + size])
        if cap is not None and len(out) >= cap:
            break
    return out

def build_arrays(files, labels):
    """Return dict with LSTM + CNN base windows, labels, and file ids."""
    seq_X, seq_y, seq_f = [], [], []
    cnn_X, cnn_y, cnn_f = [], [], []
    for fid, (path, lab) in enumerate(zip(files, labels)):
        seq, roll = extract_both(path)
        if seq is not None:
            for w in windows_1d(seq, SEQ_LEN, SEQ_STRIDE):
                seq_X.append(w); seq_y.append(lab); seq_f.append(fid)
        if roll is not None:
            for w in windows_2d(roll, PR_TIME, PR_STRIDE):
                cnn_X.append(w); cnn_y.append(lab); cnn_f.append(fid)
    return {
        "seq": (np.array(seq_X, np.int16), np.array(seq_y, np.int32), np.array(seq_f)),
        "cnn": (np.array(cnn_X, np.uint8)[..., None], np.array(cnn_y, np.int32), np.array(cnn_f)),
    }

def cached_build_arrays(tag, split, files, labels):
    """Extraction is deterministic given (cap, split), so cache it to disk.
    Delete build/fc_cache/ if you change any window/extraction parameter."""
    p = CACHE_DIR / f"{tag}_{split}.npz"
    if p.exists():
        z = np.load(p)
        print(f"  [{tag}/{split}] loaded from cache")
        return {"seq": (z["sX"], z["sy"], z["sf"]),
                "cnn": (z["cX"], z["cy"], z["cf"])}
    out = build_arrays(files, labels)
    (sX, sy, sf), (cX, cy, cf) = out["seq"], out["cnn"]
    np.savez_compressed(p, sX=sX, sy=sy, sf=sf, cX=cX, cy=cy, cf=cf)
    print(f"  [{tag}/{split}] extracted and cached -> {p}")
    return out

print("Extraction helpers defined.")
# Out:
# Extraction helpers defined.

# %% [markdown]
# ## 4. tf.data pipelines
#
# Training windows get a random semitone shift from {-2,-1,0,+1,+2} each epoch.
# The team notebook baked in all four shifts as extra copies; sampling them
# randomly covers the same space without the 5x memory. Validation and test are
# never augmented.

# %%
SHIFTS = tf.constant([0] + AUG_SEMITONES, dtype=tf.int32)

def _aug_seq(x, y):
    s = SHIFTS[tf.random.uniform([], 0, len(AUG_SEMITONES) + 1, tf.int32)]
    x = tf.clip_by_value(tf.cast(x, tf.int32) + s, 0, 127)
    return x, y

def _shift_roll(x, s):
    # x: (128, T, 1). Row index = pitch, so shifting rows transposes.
    def up():   return tf.pad(x, [[s, 0], [0, 0], [0, 0]])[:PR_PITCH]
    def down(): return tf.pad(x, [[0, -s], [0, 0], [0, 0]])[-PR_PITCH:]
    return tf.cond(s > 0, up, down)

def _aug_roll(x, y):
    s = SHIFTS[tf.random.uniform([], 0, len(AUG_SEMITONES) + 1, tf.int32)]
    x = tf.cond(tf.equal(s, 0), lambda: x, lambda: _shift_roll(x, s))
    return x, y

def make_ds(X, y, kind, training):
    if kind == "seq":
        ds = tf.data.Dataset.from_tensor_slices((X.astype(np.int32), y))
        aug = _aug_seq
    else:
        ds = tf.data.Dataset.from_tensor_slices((X.astype(np.float32), y))
        aug = _aug_roll
    if training:
        ds = ds.shuffle(min(len(y), 20000), seed=SEED).map(
            aug, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Pipelines defined.")
# Out:
# Pipelines defined.

# %% [markdown]
# ## 5. Models — identical architectures to the team notebook
#
# `USE_BATCHNORM=False` reproduces the ablation the team flagged as future work
# (BatchNorm on sparse binary input is suspected of destabilizing validation).

# %%
def build_lstm(lr, dropout):
    set_seeds()
    m = models.Sequential([
        layers.Input(shape=(SEQ_LEN,)),
        layers.Embedding(input_dim=129, output_dim=64),
        layers.LSTM(128, return_sequences=True, dropout=dropout),
        layers.LSTM(64, dropout=dropout),
        layers.Dense(64, activation="relu"),
        layers.Dropout(dropout),
        layers.Dense(len(TARGET_COMPOSERS), activation="softmax", dtype="float32"),
    ], name="LSTM_full_corpus")
    m.compile(optimizer=optimizers.Adam(lr),
              loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return m

def build_cnn(lr, dropout):
    set_seeds()
    L = [layers.Input(shape=(PR_PITCH, PR_TIME, 1))]
    for f in (32, 64, 128):
        L.append(layers.Conv2D(f, 3, padding="same", activation="relu"))
        if USE_BATCHNORM:
            # BatchNorm running stats are fragile on sparse binary inputs;
            # disable with USE_BATCHNORM=False if training under mixed_float16.
            L.append(layers.BatchNormalization())
        L.append(layers.MaxPooling2D(2))
    L += [layers.GlobalAveragePooling2D(),
          layers.Dense(128, activation="relu"),
          layers.Dropout(dropout),
          layers.Dense(len(TARGET_COMPOSERS), activation="softmax", dtype="float32")]
    m = models.Sequential(L, name="CNN_full_corpus")
    m.compile(optimizer=optimizers.Adam(lr),
              loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return m

print("Model builders defined.")
# Out:
# Model builders defined.

# %% [markdown]
# ## 6. Training and evaluation
#
# Same callbacks as the team notebook (early stopping on val loss with best-weights
# restore, checkpoint, LR reduction). Checkpoints are tagged with the cap so a
# 75-cap model can't get mixed up with a full-corpus one, and nothing is loaded
# from disk: every number below comes from a model trained in this session (we got
# burned by stale checkpoints in the main notebook review).
#
# `evaluate_two_level` reports metrics per window and per piece. Piece-level =
# average the window probability vectors of each file, then take the argmax.

# %%
def train(build_fn, cfg, tr_ds, va_ds, class_weight, tag):
    model = build_fn(**cfg)
    cbs = [
        callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE,
                                restore_best_weights=True),
        callbacks.ModelCheckpoint(str(ARTIFACTS_DIR / f"{tag}.keras"),
                                  monitor="val_loss", save_best_only=True),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                                    patience=3, min_lr=1e-5),
    ]
    hist = model.fit(tr_ds, validation_data=va_ds, epochs=MAX_EPOCHS,
                     class_weight=class_weight, callbacks=cbs, verbose=2)
    return model, hist

def evaluate_two_level(model, X, y, file_ids, kind, title):
    ds = make_ds(X, y, kind, training=False)
    proba = model.predict(ds, verbose=0)

    # ---- window level ----
    yw = proba.argmax(1)
    acc_w = accuracy_score(y, yw)
    pw, rw, fw, _ = precision_recall_fscore_support(y, yw, average="macro", zero_division=0)

    # ---- piece level: average window probabilities per file ----
    pieces = pd.DataFrame(proba)
    pieces["fid"] = file_ids
    pieces["true"] = y
    agg = pieces.groupby("fid").agg({**{i: "mean" for i in range(len(TARGET_COMPOSERS))},
                                     "true": "first"})
    yp_true = agg["true"].values
    yp_pred = agg[list(range(len(TARGET_COMPOSERS)))].values.argmax(1)
    acc_p = accuracy_score(yp_true, yp_pred)
    pp, rp, fp_, _ = precision_recall_fscore_support(yp_true, yp_pred,
                                                     average="macro", zero_division=0)

    print(f"===== {title} =====")
    print(f"window: acc={acc_w:.4f}  macro P/R/F1 = {pw:.3f}/{rw:.3f}/{fw:.3f}  (n={len(y)})")
    print(f"piece : acc={acc_p:.4f}  macro P/R/F1 = {pp:.3f}/{rp:.3f}/{fp_:.3f}  (n={len(yp_true)})")
    print(classification_report(yp_true, yp_pred, target_names=TARGET_COMPOSERS,
                                zero_division=0))
    fig, ax = plt.subplots(figsize=(4.5, 3.5))
    sns.heatmap(confusion_matrix(yp_true, yp_pred), annot=True, fmt="d", cmap="Blues",
                xticklabels=TARGET_COMPOSERS, yticklabels=TARGET_COMPOSERS, ax=ax)
    ax.set_title(f"{title} - piece-level confusion"); ax.set_xlabel("predicted"); ax.set_ylabel("true")
    plt.tight_layout(); plt.show()

    return {"acc_window": acc_w, "f1_macro_window": fw,
            "acc_piece": acc_p, "f1_macro_piece": fp_,
            "precision_macro_piece": pp, "recall_macro_piece": rp}

print("Train/eval utilities defined.")
# Out:
# Train/eval utilities defined.

# %% [markdown]
# ## 7. Run both experiments (cap = 75, then full corpus)

# %%
def run_experiment(cap):
    tag = f"cap{cap}" if cap else "full"
    print(f"\n{'='*60}\nEXPERIMENT: {tag}\n{'='*60}")
    set_seeds()

    files = clean_df["path"].values
    labels = clean_df["composer"].map(LABEL2IDX).values
    if cap is not None:
        keep = []
        rng = np.random.RandomState(SEED)
        for c in range(len(TARGET_COMPOSERS)):
            idx = np.where(labels == c)[0]
            rng.shuffle(idx)
            keep.extend(idx[:cap])
        keep = np.array(sorted(keep))
        files, labels = files[keep], labels[keep]

    f_tv, f_te, y_tv, y_te = train_test_split(files, labels, test_size=TEST_SIZE,
                                              stratify=labels, random_state=SEED)
    f_tr, f_va, y_tr, y_va = train_test_split(f_tv, y_tv,
                                              test_size=VAL_SIZE / (1 - TEST_SIZE),
                                              stratify=y_tv, random_state=SEED)
    assert not (set(f_tr) & set(f_te)) and not (set(f_tr) & set(f_va)) \
           and not (set(f_va) & set(f_te)), "split leakage!"
    print(f"files -> train {len(f_tr)}  val {len(f_va)}  test {len(f_te)}")

    tr = cached_build_arrays(tag, "train", f_tr, y_tr)
    va = cached_build_arrays(tag, "val",   f_va, y_va)
    te = cached_build_arrays(tag, "test",  f_te, y_te)

    rows = {}
    for kind, build_fn, cfg, name in [("seq", build_lstm, LSTM_CFG, "LSTM"),
                                      ("cnn", build_cnn, CNN_CFG, "CNN")]:
        Xtr, ytr, _ = tr[kind]
        Xva, yva, _ = va[kind]
        Xte, yte, fte = te[kind]
        mb = Xtr.nbytes / 1e6
        print(f"\n--- {name} [{tag}] --- train windows: {len(ytr)} ({mb:.0f} MB)")
        cw = compute_class_weight("balanced", classes=np.arange(len(TARGET_COMPOSERS)), y=ytr)
        cw = {int(i): float(w) for i, w in enumerate(cw)}
        model, hist = train(build_fn, cfg,
                            make_ds(Xtr, ytr, kind, True),
                            make_ds(Xva, yva, kind, False),
                            cw, tag=f"{name.lower()}_{tag}")
        metrics = evaluate_two_level(model, Xte, yte, fte, kind, f"{name} [{tag}]")
        rows[name] = {"experiment": tag, "model": name,
                      "train_files": len(f_tr), "train_windows": len(ytr), **metrics}
    return rows

all_rows = []
for cap in EXPERIMENT_CAPS:
    res = run_experiment(cap)
    all_rows += list(res.values())
# Out:
# ============================================================
# EXPERIMENT: cap75
# ============================================================
# files -> train 210  val 45  test 45
#   [cap75/train] loaded from cache
#   [cap75/val] loaded from cache
#   [cap75/test] loaded from cache
#
# --- LSTM [cap75] --- train windows: 3422 (1 MB)
# Epoch 1/60
# 54/54 - 5s - 99ms/step - accuracy: 0.2712 - loss: 1.3861 - val_accuracy: 0.3207 - val_loss: 1.3709 - learning_rate: 0.0010
# Epoch 2/60
# 54/54 - 2s - 44ms/step - accuracy: 0.3019 - loss: 1.3597 - val_accuracy: 0.2437 - val_loss: 1.3892 - learning_rate: 0.0010
# Epoch 3/60
# 54/54 - 2s - 45ms/step - accuracy: 0.3387 - loss: 1.3267 - val_accuracy: 0.3880 - val_loss: 1.3076 - learning_rate: 0.0010
# Epoch 4/60
# 54/54 - 2s - 43ms/step - accuracy: 0.3486 - loss: 1.3176 - val_accuracy: 0.2745 - val_loss: 1.4155 - learning_rate: 0.0010
# Epoch 5/60
# 54/54 - 2s - 43ms/step - accuracy: 0.3764 - loss: 1.2900 - val_accuracy: 0.2773 - val_loss: 1.4006 - learning_rate: 0.0010
# Epoch 6/60
# 54/54 - 2s - 43ms/step - accuracy: 0.3714 - loss: 1.2857 - val_accuracy: 0.2885 - val_loss: 1.3666 - learning_rate: 0.0010
# Epoch 7/60
# 54/54 - 2s - 42ms/step - accuracy: 0.3776 - loss: 1.2615 - val_accuracy: 0.3249 - val_loss: 1.3144 - learning_rate: 5.0000e-04
# Epoch 8/60
# 54/54 - 2s - 42ms/step - accuracy: 0.3811 - loss: 1.2782 - val_accuracy: 0.3039 - val_loss: 1.3737 - learning_rate: 5.0000e-04
# Epoch 9/60
# 54/54 - 2s - 44ms/step - accuracy: 0.4018 - loss: 1.2469 - val_accuracy: 0.3417 - val_loss: 1.3152 - learning_rate: 5.0000e-04
# Epoch 10/60
# 54/54 - 2s - 43ms/step - accuracy: 0.4112 - loss: 1.2285 - val_accuracy: 0.3431 - val_loss: 1.3190 - learning_rate: 2.5000e-04
# Epoch 11/60
# 54/54 - 2s - 44ms/step - accuracy: 0.4191 - loss: 1.2237 - val_accuracy: 0.3333 - val_loss: 1.3059 - learning_rate: 2.5000e-04
# Epoch 12/60
# 54/54 - 2s - 38ms/step - accuracy: 0.4164 - loss: 1.2080 - val_accuracy: 0.3193 - val_loss: 1.3492 - learning_rate: 2.5000e-04
# Epoch 13/60
# 54/54 - 2s - 36ms/step - accuracy: 0.4144 - loss: 1.2188 - val_accuracy: 0.3277 - val_loss: 1.3224 - learning_rate: 2.5000e-04
# Epoch 14/60
# 54/54 - 2s - 45ms/step - accuracy: 0.4074 - loss: 1.2173 - val_accuracy: 0.3361 - val_loss: 1.3258 - learning_rate: 2.5000e-04
# Epoch 15/60
# 54/54 - 2s - 42ms/step - accuracy: 0.4226 - loss: 1.1914 - val_accuracy: 0.3445 - val_loss: 1.3171 - learning_rate: 1.2500e-04
# Epoch 16/60
# 54/54 - 2s - 42ms/step - accuracy: 0.4278 - loss: 1.1924 - val_accuracy: 0.3417 - val_loss: 1.3286 - learning_rate: 1.2500e-04
# Epoch 17/60
# 54/54 - 2s - 42ms/step - accuracy: 0.4234 - loss: 1.2015 - val_accuracy: 0.3305 - val_loss: 1.3322 - learning_rate: 1.2500e-04
# Epoch 18/60
# 54/54 - 2s - 43ms/step - accuracy: 0.4234 - loss: 1.2010 - val_accuracy: 0.3347 - val_loss: 1.3143 - learning_rate: 6.2500e-05
# Epoch 19/60
# 54/54 - 2s - 43ms/step - accuracy: 0.4261 - loss: 1.1903 - val_accuracy: 0.3389 - val_loss: 1.3290 - learning_rate: 6.2500e-05
# ===== LSTM [cap75] =====
# window: acc=0.3486  macro P/R/F1 = 0.416/0.393/0.342  (n=740)
# piece : acc=0.4889  macro P/R/F1 = 0.607/0.494/0.480  (n=45)
#               precision    recall  f1-score   support
#
#         Bach       0.38      0.73      0.50        11
#    Beethoven       0.55      0.55      0.55        11
#       Chopin       1.00      0.25      0.40        12
#       Mozart       0.50      0.45      0.48        11
#
#     accuracy                           0.49        45
#    macro avg       0.61      0.49      0.48        45
# weighted avg       0.62      0.49      0.48        45
# --- CNN [cap75] --- train windows: 3207 (53 MB)
# Epoch 1/60
# 51/51 - 9s - 171ms/step - accuracy: 0.4054 - loss: 1.2587 - val_accuracy: 0.3284 - val_loss: 1.4073 - learning_rate: 5.0000e-04
# Epoch 2/60
# 51/51 - 1s - 28ms/step - accuracy: 0.5497 - loss: 1.0139 - val_accuracy: 0.1486 - val_loss: 1.5459 - learning_rate: 5.0000e-04
# Epoch 3/60
# 51/51 - 1s - 28ms/step - accuracy: 0.6152 - loss: 0.8795 - val_accuracy: 0.1486 - val_loss: 1.9145 - learning_rate: 5.0000e-04
# Epoch 4/60
# 51/51 - 1s - 28ms/step - accuracy: 0.6448 - loss: 0.8010 - val_accuracy: 0.1486 - val_loss: 2.8402 - learning_rate: 5.0000e-04
# Epoch 5/60
# 51/51 - 1s - 28ms/step - accuracy: 0.6925 - loss: 0.7148 - val_accuracy: 0.1486 - val_loss: 3.9218 - learning_rate: 2.5000e-04
# Epoch 6/60
# 51/51 - 1s - 27ms/step - accuracy: 0.7141 - loss: 0.6721 - val_accuracy: 0.1486 - val_loss: 5.6762 - learning_rate: 2.5000e-04
# Epoch 7/60
# 51/51 - 1s - 27ms/step - accuracy: 0.7309 - loss: 0.6351 - val_accuracy: 0.1501 - val_loss: 6.1165 - learning_rate: 2.5000e-04
# Epoch 8/60
# 51/51 - 1s - 27ms/step - accuracy: 0.7565 - loss: 0.5906 - val_accuracy: 0.1530 - val_loss: 6.7590 - learning_rate: 1.2500e-04
# Epoch 9/60
# 51/51 - 1s - 28ms/step - accuracy: 0.7677 - loss: 0.5722 - val_accuracy: 0.1605 - val_loss: 6.5338 - learning_rate: 1.2500e-04
# ===== CNN [cap75] =====
# window: acc=0.2857  macro P/R/F1 = 0.237/0.258/0.127  (n=707)
# piece : acc=0.2444  macro P/R/F1 = 0.061/0.250/0.098  (n=45)
#               precision    recall  f1-score   support
#
#         Bach       0.00      0.00      0.00        11
#    Beethoven       0.00      0.00      0.00        11
#       Chopin       0.00      0.00      0.00        12
#       Mozart       0.24      1.00      0.39        11
#
#     accuracy                           0.24        45
#    macro avg       0.06      0.25      0.10        45
# weighted avg       0.06      0.24      0.10        45
# ============================================================
# EXPERIMENT: full
# ============================================================
# files -> train 1123  val 241  test 241
#   [full/train] loaded from cache
#   [full/val] loaded from cache
#   [full/test] loaded from cache
#
# --- LSTM [full] --- train windows: 15833 (3 MB)
# Epoch 1/60
# 248/248 - 9s - 36ms/step - accuracy: 0.4575 - loss: 1.3370 - val_accuracy: 0.5753 - val_loss: 1.1632 - learning_rate: 0.0010
# Epoch 2/60
# 248/248 - 8s - 30ms/step - accuracy: 0.5117 - loss: 1.3010 - val_accuracy: 0.4921 - val_loss: 1.2443 - learning_rate: 0.0010
# Epoch 3/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5086 - loss: 1.2887 - val_accuracy: 0.5324 - val_loss: 1.2143 - learning_rate: 0.0010
# Epoch 4/60
# 248/248 - 8s - 33ms/step - accuracy: 0.5273 - loss: 1.2612 - val_accuracy: 0.5750 - val_loss: 1.0890 - learning_rate: 0.0010
# Epoch 5/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5123 - loss: 1.2507 - val_accuracy: 0.5587 - val_loss: 1.1110 - learning_rate: 0.0010
# Epoch 6/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5280 - loss: 1.2320 - val_accuracy: 0.5245 - val_loss: 1.1459 - learning_rate: 0.0010
# Epoch 7/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5441 - loss: 1.1998 - val_accuracy: 0.5374 - val_loss: 1.1135 - learning_rate: 0.0010
# Epoch 8/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5594 - loss: 1.1466 - val_accuracy: 0.5908 - val_loss: 1.0236 - learning_rate: 5.0000e-04
# Epoch 9/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5722 - loss: 1.1237 - val_accuracy: 0.5683 - val_loss: 1.0988 - learning_rate: 5.0000e-04
# Epoch 10/60
# 248/248 - 8s - 33ms/step - accuracy: 0.5615 - loss: 1.1253 - val_accuracy: 0.5248 - val_loss: 1.0768 - learning_rate: 5.0000e-04
# Epoch 11/60
# 248/248 - 8s - 32ms/step - accuracy: 0.5626 - loss: 1.1108 - val_accuracy: 0.6033 - val_loss: 1.0000 - learning_rate: 5.0000e-04
# Epoch 12/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5845 - loss: 1.0910 - val_accuracy: 0.6293 - val_loss: 0.9579 - learning_rate: 5.0000e-04
# Epoch 13/60
# 248/248 - 8s - 31ms/step - accuracy: 0.5898 - loss: 1.0683 - val_accuracy: 0.6457 - val_loss: 0.9177 - learning_rate: 5.0000e-04
# Epoch 14/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6035 - loss: 1.0567 - val_accuracy: 0.6500 - val_loss: 0.9237 - learning_rate: 5.0000e-04
# Epoch 15/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6089 - loss: 1.0463 - val_accuracy: 0.6419 - val_loss: 0.9384 - learning_rate: 5.0000e-04
# Epoch 16/60
# 248/248 - 8s - 33ms/step - accuracy: 0.6073 - loss: 1.0387 - val_accuracy: 0.6232 - val_loss: 0.9776 - learning_rate: 5.0000e-04
# Epoch 17/60
# 248/248 - 8s - 32ms/step - accuracy: 0.6139 - loss: 1.0232 - val_accuracy: 0.6386 - val_loss: 0.9501 - learning_rate: 2.5000e-04
# Epoch 18/60
# 248/248 - 8s - 32ms/step - accuracy: 0.6214 - loss: 1.0007 - val_accuracy: 0.6623 - val_loss: 0.8996 - learning_rate: 2.5000e-04
# Epoch 19/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6264 - loss: 0.9950 - val_accuracy: 0.6506 - val_loss: 0.9267 - learning_rate: 2.5000e-04
# Epoch 20/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6311 - loss: 0.9853 - val_accuracy: 0.6567 - val_loss: 0.9181 - learning_rate: 2.5000e-04
# Epoch 21/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6296 - loss: 0.9827 - val_accuracy: 0.6716 - val_loss: 0.8772 - learning_rate: 2.5000e-04
# Epoch 22/60
# 248/248 - 8s - 33ms/step - accuracy: 0.6389 - loss: 0.9706 - val_accuracy: 0.6743 - val_loss: 0.8711 - learning_rate: 2.5000e-04
# Epoch 23/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6365 - loss: 0.9611 - val_accuracy: 0.6529 - val_loss: 0.9060 - learning_rate: 2.5000e-04
# Epoch 24/60
# 248/248 - 8s - 30ms/step - accuracy: 0.6328 - loss: 0.9663 - val_accuracy: 0.6775 - val_loss: 0.8706 - learning_rate: 2.5000e-04
# Epoch 25/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6495 - loss: 0.9568 - val_accuracy: 0.6751 - val_loss: 0.8818 - learning_rate: 2.5000e-04
# Epoch 26/60
# 248/248 - 7s - 30ms/step - accuracy: 0.6436 - loss: 0.9486 - val_accuracy: 0.6725 - val_loss: 0.8853 - learning_rate: 2.5000e-04
# Epoch 27/60
# 248/248 - 8s - 30ms/step - accuracy: 0.6508 - loss: 0.9339 - val_accuracy: 0.6716 - val_loss: 0.8883 - learning_rate: 2.5000e-04
# Epoch 28/60
# 248/248 - 8s - 33ms/step - accuracy: 0.6555 - loss: 0.9220 - val_accuracy: 0.6754 - val_loss: 0.8724 - learning_rate: 1.2500e-04
# Epoch 29/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6606 - loss: 0.9150 - val_accuracy: 0.6891 - val_loss: 0.8521 - learning_rate: 1.2500e-04
# Epoch 30/60
# 248/248 - 7s - 30ms/step - accuracy: 0.6580 - loss: 0.9164 - val_accuracy: 0.6836 - val_loss: 0.8732 - learning_rate: 1.2500e-04
# Epoch 31/60
# 248/248 - 8s - 30ms/step - accuracy: 0.6578 - loss: 0.9081 - val_accuracy: 0.6792 - val_loss: 0.8623 - learning_rate: 1.2500e-04
# Epoch 32/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6581 - loss: 0.9110 - val_accuracy: 0.6859 - val_loss: 0.8557 - learning_rate: 1.2500e-04
# Epoch 33/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6631 - loss: 0.9032 - val_accuracy: 0.6851 - val_loss: 0.8586 - learning_rate: 6.2500e-05
# Epoch 34/60
# 248/248 - 8s - 32ms/step - accuracy: 0.6633 - loss: 0.9023 - val_accuracy: 0.6877 - val_loss: 0.8451 - learning_rate: 6.2500e-05
# Epoch 35/60
# 248/248 - 8s - 33ms/step - accuracy: 0.6670 - loss: 0.8914 - val_accuracy: 0.6883 - val_loss: 0.8431 - learning_rate: 6.2500e-05
# Epoch 36/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6690 - loss: 0.8951 - val_accuracy: 0.6804 - val_loss: 0.8529 - learning_rate: 6.2500e-05
# Epoch 37/60
# 248/248 - 8s - 30ms/step - accuracy: 0.6684 - loss: 0.8887 - val_accuracy: 0.6856 - val_loss: 0.8545 - learning_rate: 6.2500e-05
# Epoch 38/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6691 - loss: 0.8839 - val_accuracy: 0.6883 - val_loss: 0.8461 - learning_rate: 6.2500e-05
# Epoch 39/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6663 - loss: 0.8879 - val_accuracy: 0.6903 - val_loss: 0.8399 - learning_rate: 3.1250e-05
# Epoch 40/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6648 - loss: 0.8844 - val_accuracy: 0.6883 - val_loss: 0.8408 - learning_rate: 3.1250e-05
# Epoch 41/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6702 - loss: 0.8835 - val_accuracy: 0.6900 - val_loss: 0.8405 - learning_rate: 3.1250e-05
# Epoch 42/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6695 - loss: 0.8769 - val_accuracy: 0.6845 - val_loss: 0.8476 - learning_rate: 3.1250e-05
# Epoch 43/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6749 - loss: 0.8731 - val_accuracy: 0.6842 - val_loss: 0.8474 - learning_rate: 1.5625e-05
# Epoch 44/60
# 248/248 - 8s - 32ms/step - accuracy: 0.6673 - loss: 0.8764 - val_accuracy: 0.6906 - val_loss: 0.8345 - learning_rate: 1.5625e-05
# Epoch 45/60
# 248/248 - 8s - 32ms/step - accuracy: 0.6733 - loss: 0.8707 - val_accuracy: 0.6918 - val_loss: 0.8348 - learning_rate: 1.5625e-05
# Epoch 46/60
# 248/248 - 8s - 33ms/step - accuracy: 0.6704 - loss: 0.8776 - val_accuracy: 0.6903 - val_loss: 0.8372 - learning_rate: 1.5625e-05
# Epoch 47/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6744 - loss: 0.8775 - val_accuracy: 0.6883 - val_loss: 0.8417 - learning_rate: 1.5625e-05
# Epoch 48/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6704 - loss: 0.8782 - val_accuracy: 0.6912 - val_loss: 0.8389 - learning_rate: 1.0000e-05
# Epoch 49/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6678 - loss: 0.8755 - val_accuracy: 0.6897 - val_loss: 0.8409 - learning_rate: 1.0000e-05
# Epoch 50/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6737 - loss: 0.8778 - val_accuracy: 0.6894 - val_loss: 0.8389 - learning_rate: 1.0000e-05
# Epoch 51/60
# 248/248 - 8s - 31ms/step - accuracy: 0.6694 - loss: 0.8761 - val_accuracy: 0.6888 - val_loss: 0.8405 - learning_rate: 1.0000e-05
# Epoch 52/60
# 248/248 - 8s - 33ms/step - accuracy: 0.6707 - loss: 0.8778 - val_accuracy: 0.6909 - val_loss: 0.8389 - learning_rate: 1.0000e-05
# ===== LSTM [full] =====
# window: acc=0.6938  macro P/R/F1 = 0.626/0.640/0.623  (n=3312)
# piece : acc=0.8672  macro P/R/F1 = 0.805/0.793/0.794  (n=241)
#               precision    recall  f1-score   support
#
#         Bach       0.94      0.95      0.94       152
#    Beethoven       0.78      0.58      0.67        31
#       Chopin       0.82      0.90      0.86        20
#       Mozart       0.68      0.74      0.71        38
#
#     accuracy                           0.87       241
#    macro avg       0.80      0.79      0.79       241
# weighted avg       0.87      0.87      0.86       241
# --- CNN [full] --- train windows: 14616 (239 MB)
# 2026-07-25 11:20:18.946164: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 957874176 exceeds 10% of free system memory.
# 2026-07-25 11:20:20.003776: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 957874176 exceeds 10% of free system memory.
# Epoch 1/60
# 229/229 - 14s - 63ms/step - accuracy: 0.5869 - loss: 1.0522 - val_accuracy: 0.5419 - val_loss: 1.3836 - learning_rate: 5.0000e-04
# Epoch 2/60
# 229/229 - 6s - 27ms/step - accuracy: 0.6959 - loss: 0.8193 - val_accuracy: 0.1634 - val_loss: 3.5288 - learning_rate: 5.0000e-04
# Epoch 3/60
# 229/229 - 6s - 27ms/step - accuracy: 0.7311 - loss: 0.7238 - val_accuracy: 0.3683 - val_loss: 2.2529 - learning_rate: 5.0000e-04
# Epoch 4/60
# 229/229 - 6s - 28ms/step - accuracy: 0.7583 - loss: 0.6453 - val_accuracy: 0.1996 - val_loss: 7.6972 - learning_rate: 5.0000e-04
# Epoch 5/60
# 229/229 - 6s - 28ms/step - accuracy: 0.7943 - loss: 0.5653 - val_accuracy: 0.6761 - val_loss: 0.9802 - learning_rate: 2.5000e-04
# Epoch 6/60
# 229/229 - 6s - 27ms/step - accuracy: 0.8045 - loss: 0.5364 - val_accuracy: 0.6412 - val_loss: 1.0345 - learning_rate: 2.5000e-04
# Epoch 7/60
# 229/229 - 6s - 28ms/step - accuracy: 0.8168 - loss: 0.5017 - val_accuracy: 0.6992 - val_loss: 0.8837 - learning_rate: 2.5000e-04
# Epoch 8/60
# 229/229 - 6s - 28ms/step - accuracy: 0.8303 - loss: 0.4672 - val_accuracy: 0.6396 - val_loss: 1.2927 - learning_rate: 2.5000e-04
# Epoch 9/60
# 229/229 - 6s - 28ms/step - accuracy: 0.8430 - loss: 0.4386 - val_accuracy: 0.3385 - val_loss: 2.2988 - learning_rate: 2.5000e-04
# Epoch 10/60
# 229/229 - 6s - 28ms/step - accuracy: 0.8518 - loss: 0.4143 - val_accuracy: 0.6390 - val_loss: 1.1303 - learning_rate: 2.5000e-04
# Epoch 11/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8735 - loss: 0.3708 - val_accuracy: 0.7084 - val_loss: 0.7574 - learning_rate: 1.2500e-04
# Epoch 12/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8746 - loss: 0.3495 - val_accuracy: 0.7576 - val_loss: 0.7585 - learning_rate: 1.2500e-04
# Epoch 13/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8800 - loss: 0.3424 - val_accuracy: 0.5768 - val_loss: 1.1852 - learning_rate: 1.2500e-04
# Epoch 14/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8896 - loss: 0.3239 - val_accuracy: 0.7582 - val_loss: 0.6901 - learning_rate: 1.2500e-04
# Epoch 15/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8927 - loss: 0.3069 - val_accuracy: 0.7278 - val_loss: 0.8114 - learning_rate: 1.2500e-04
# Epoch 16/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8945 - loss: 0.3035 - val_accuracy: 0.7100 - val_loss: 0.8201 - learning_rate: 1.2500e-04
# Epoch 17/60
# 229/229 - 7s - 29ms/step - accuracy: 0.8959 - loss: 0.2889 - val_accuracy: 0.7706 - val_loss: 0.6453 - learning_rate: 1.2500e-04
# Epoch 18/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9074 - loss: 0.2691 - val_accuracy: 0.7313 - val_loss: 0.7275 - learning_rate: 1.2500e-04
# Epoch 19/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9087 - loss: 0.2668 - val_accuracy: 0.7072 - val_loss: 0.8627 - learning_rate: 1.2500e-04
# Epoch 20/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9100 - loss: 0.2538 - val_accuracy: 0.7199 - val_loss: 0.9392 - learning_rate: 1.2500e-04
# Epoch 21/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9225 - loss: 0.2341 - val_accuracy: 0.7576 - val_loss: 0.7297 - learning_rate: 6.2500e-05
# Epoch 22/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9284 - loss: 0.2192 - val_accuracy: 0.7468 - val_loss: 0.7353 - learning_rate: 6.2500e-05
# Epoch 23/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9276 - loss: 0.2169 - val_accuracy: 0.7681 - val_loss: 0.6839 - learning_rate: 6.2500e-05
# Epoch 24/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9319 - loss: 0.2096 - val_accuracy: 0.7709 - val_loss: 0.6789 - learning_rate: 3.1250e-05
# Epoch 25/60
# 229/229 - 7s - 29ms/step - accuracy: 0.9361 - loss: 0.2005 - val_accuracy: 0.7843 - val_loss: 0.6508 - learning_rate: 3.1250e-05
# ===== CNN [full] =====
# window: acc=0.7389  macro P/R/F1 = 0.658/0.687/0.657  (n=3007)
# piece : acc=0.8880  macro P/R/F1 = 0.818/0.814/0.806  (n=241)
#               precision    recall  f1-score   support
#
#         Bach       0.96      0.97      0.97       152
#    Beethoven       0.80      0.52      0.63        31
#       Chopin       0.79      0.95      0.86        20
#       Mozart       0.72      0.82      0.77        38
#
#     accuracy                           0.89       241
#    macro avg       0.82      0.81      0.81       241
# weighted avg       0.89      0.89      0.88       241

# %% [markdown]
# ## 8. Comparison table

# %%
comparison = pd.DataFrame(all_rows).set_index(["experiment", "model"]).round(4)
print(comparison)
comparison.to_csv(OUT_DIR / "full_corpus_comparison.csv")

fig, ax = plt.subplots(figsize=(8, 4))
plot_df = comparison.reset_index()
plot_df["label"] = plot_df["experiment"] + " / " + plot_df["model"]
x = np.arange(len(plot_df)); w = 0.35
ax.bar(x - w/2, plot_df["acc_window"], w, label="window-level acc")
ax.bar(x + w/2, plot_df["acc_piece"],  w, label="piece-level acc")
ax.set_xticks(x); ax.set_xticklabels(plot_df["label"], rotation=15)
ax.axhline(0.25, ls="--", c="gray", lw=1, label="chance (25%)")
ax.set_ylim(0, 1); ax.legend(); ax.set_title("Cap-75 vs full corpus, window vs piece level")
plt.tight_layout(); plt.savefig(OUT_DIR / "full_corpus_comparison.png", dpi=150); plt.show()
print("Saved:", OUT_DIR / "full_corpus_comparison.csv")
# Out:
#                   train_files  train_windows  acc_window  f1_macro_window  \
# experiment model
# cap75      LSTM           210           3422      0.3486           0.3415
#            CNN            210           3207      0.2857           0.1269
# full       LSTM          1123          15833      0.6938           0.6231
#            CNN           1123          14616      0.7389           0.6566
#
#                   acc_piece  f1_macro_piece  precision_macro_piece  \
# experiment model
# cap75      LSTM      0.4889          0.4804                 0.6066
#            CNN       0.2444          0.0982                 0.0611
# full       LSTM      0.8672          0.7943                 0.8048
#            CNN       0.8880          0.8060                 0.8184
#
#                   recall_macro_piece
# experiment model
# cap75      LSTM               0.4943
#            CNN                0.2500
# full       LSTM               0.7929
#            CNN                0.8139
# Saved: build/fc_results/full_corpus_comparison.csv

# %% [markdown]
# ## 9. Conclusions
#
# Fill in from the section 8 table after running:
#
# - full corpus vs cap-75: CNN piece accuracy went from __ to __, LSTM from __ to __
# - piece-level vs window-level added roughly __ points
# - check the confusion matrices: did Bach stop being the weak class once all his
#   files were included?
#
# For the paper this goes in Model Optimization as the data-scaling experiment.
# The EDA (Francisco/eda/) explains why window share, not file count, drives the
# imbalance.
#
# Possible follow-up: set USE_BATCHNORM = False and rerun for the BatchNorm
# ablation we discussed.
